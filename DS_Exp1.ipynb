# %% [markdown]
# <a href="https://colab.research.google.com/github/CappyCap17/dataSciExp/blob/main/DS_Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Experiment 1**

# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#importing files
d1 = pd.read_csv('student2.csv')
d2 = pd.read_csv('student3.csv')

# %%
#performing merge operatios
d3 = pd.merge(d1,d2,on='name')

# %%
d3
# Out:
#    roll_x     name class_x  marks  age_x  roll_y class_y  marks   age_y
# 0       1     anil      TE  56.77   22.0       1      TE   56.77   22.0
# 1       2     amit      TE  59.77   21.0       2      TE   59.77   21.0
# 2       3   aniket      BE  76.88   19.0       3      BE   76.88   19.0
# 3       4  ajinkya      TE  69.66    NaN       4      TE   69.66   20.0
# 4       5     asha     NaN  63.28   20.0       5      TE   63.28    NaN
# 5       6   ayesha      BE  49.55   20.0       6      BE     NaN   20.0
# 6       7     amar      BE    NaN   19.0       7      BE   65.34   19.0
# 7       9     amol      TE  56.75   20.0       9      TE   56.75   20.0
# 8       9     amol      TE  56.75   20.0       9      TE   56.75   20.0
# 9      10    anmol      BE  78.66   21.0      10      BE   78.66    NaN

# %%
#using filter method to filter out only selected columns
d3.filter(["name","marks"])
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar    NaN
# 7     amol  56.75
# 8     amol  56.75
# 9    anmol  78.66

# %%
#sampling method
rows = d3.sample(frac =.5)
rows
# Out:
#    roll_x     name class_x  marks  age_x  roll_y class_y  marks   age_y
# 5       6   ayesha      BE  49.55   20.0       6      BE     NaN   20.0
# 2       3   aniket      BE  76.88   19.0       3      BE   76.88   19.0
# 7       9     amol      TE  56.75   20.0       9      TE   56.75   20.0
# 6       7     amar      BE    NaN   19.0       7      BE   65.34   19.0
# 3       4  ajinkya      TE  69.66    NaN       4      TE   69.66   20.0
